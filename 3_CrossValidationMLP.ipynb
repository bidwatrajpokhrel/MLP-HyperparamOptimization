# %% [markdown]
# <a href="https://colab.research.google.com/github/bidwatrajpokhrel/MLP-HyperparamOptimization/blob/master/3_CrossValidationMLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import display

# %%
#from google.colab import drive # mounts the google drive for a new notebook 
#drive.mount('/content/drive')

# %%
# load the 2 npy files created by the process_yale_images.ipynb 
from numpy import load
import numpy as np
path = '/content/drive/My Drive/BidwatPhotosSample/'
# load array
y = load(path + 'yaleExtB_target.npy')
X = load(path + 'yaleExtB_data.npy')

# %%
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

# %%
# PCA 
nof_prin_components = 200  # PARAMETER for optimisation in expereiments
pca = PCA(n_components=nof_prin_components, whiten=True).fit(X)
# applies PCA to the train and test images to calculate the principal components
X_pca = pca.transform(X)

# %%
#define the neural network
nohn = 1200 # nof hidden neurons
clf = MLPClassifier(hidden_layer_sizes=(nohn,), solver='adam', activation='relu', batch_size=256, verbose=True, early_stopping=True)

# %%
print(cross_val_score(clf, X_pca, y, cv=10).mean())
display.Javascript("google.colab.output.setIframeHeight('100px');")
# Out:
# Iteration 1, loss = 3.09892549
# Validation score: 0.585185
# Iteration 2, loss = 1.73204649
# Validation score: 0.896296
# Iteration 3, loss = 0.82845868
# Validation score: 0.940741
# Iteration 4, loss = 0.36286113
# Validation score: 0.955556
# Iteration 5, loss = 0.16784162
# Validation score: 0.970370
# Iteration 6, loss = 0.09008453
# Validation score: 0.977778
# Iteration 7, loss = 0.05415159
# Validation score: 0.977778
# Iteration 8, loss = 0.03625960
# Validation score: 0.977778
# Iteration 9, loss = 0.02637321
# Validation score: 0.977778
# Iteration 10, loss = 0.02073310
# Validation score: 0.977778
# Iteration 11, loss = 0.01714260
# Validation score: 0.977778
# Iteration 12, loss = 0.01459234
# Validation score: 0.977778
# Iteration 13, loss = 0.01276553
# Validation score: 0.977778
# Iteration 14, loss = 0.01140844
# Validation score: 0.977778
# Iteration 15, loss = 0.01037300
# Validation score: 0.977778
# Iteration 16, loss = 0.00952934
# Validation score: 0.985185
# ...
